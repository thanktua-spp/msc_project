# %%
import torch
from transformers import AutoConfig, AutoImageProcessor, AutoModel

# %%
print(torch.__version__)
print(torch.version.cuda)   # check CUDA support (None if CPU only)
print(torch.backends.mkl.is_available())  # check MKL if needed
# Out:
# 2.8.0+cu128
# 12.8
# True

# %%
from typing import Callable, Dict, Optional, Sequence, Tuple, Union

import torch
import torch.nn as nn
import torchvision
from rich import print

# %%
torch.tensor([1, 2, 3])
# Out:
# tensor([1, 2, 3])

# %% [markdown]
# # ResNet Embedding

# %%
resnet_model = torchvision.models.get_model("resnet18", weights=None)
type(resnet_model)
# Out:
# torchvision.models.resnet.ResNet

# %%
resnet_model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
print(resnet_model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
resnet_model.fc = torch.nn.Identity()
print(resnet_model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# using standard ResNet implementation from torchvision
def get_resnet(name: str, weights=None, **kwargs) -> nn.Module:
    resnet_func = torchvision.models.resnet18
    resnet_model = resnet_func(weights=weights, **kwargs)

    # remove the final 1000 target classification layer for resnet18 and keep 512
    # https://docs.pytorch.org/docs/stable/generated/torch.nn.Identity.html
    resnet_model.fc = torch.nn.Identity()
    return resnet_model


# construct a ResNet model with no pretrained weights
vision_encoder = get_resnet("resnet18", weights=None)
print(vision_encoder)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
list(resnet_model.named_modules())
# Out:
# [('',
#   ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
sequential_blocks = [module for name, module in resnet_model.named_modules() if isinstance(module, nn.Sequential)]
[module for seq_block in sequential_blocks
                  for name, module in seq_block.named_modules()
                  if isinstance(module, nn.BatchNorm2d)]
# Out:
# [BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
# ...

# %%
def count_parameters(model):
   return sum(p.numel() for p in model.parameters())

# %%
def replace_submodules(
        root_module: nn.Module,
        predicate: Callable[[nn.Module], bool],
        func: Callable[[nn.Module], nn.Module]) -> nn.Module:
    """
    Replace all submodules selected by the predicate with
    the output of func.

    predicate: Return true if the module is to be replaced.
    func: Return new module to use.
    """
    if predicate(root_module):
        return func(root_module)

    bn_list = [k.split('.') for k, m
        in root_module.named_modules(remove_duplicate=True)
        if predicate(m)]
    for *parent, k in bn_list:
        parent_module = root_module
        if len(parent) > 0:
            parent_module = root_module.get_submodule('.'.join(parent))
        if isinstance(parent_module, nn.Sequential):
            src_module = parent_module[int(k)]
        else:
            src_module = getattr(parent_module, k)
        tgt_module = func(src_module)
        if isinstance(parent_module, nn.Sequential):
            parent_module[int(k)] = tgt_module
        else:
            setattr(parent_module, k, tgt_module)
    # verify that all modules are replaced
    bn_list = [k.split('.') for k, m
        in root_module.named_modules(remove_duplicate=True)
        if predicate(m)]
    assert len(bn_list) == 0
    return root_module

def replace_bn_with_gn(
    root_module: nn.Module,
    features_per_group: int=16) -> nn.Module:
    """
    Relace all BatchNorm layers with GroupNorm.
    """
    replace_submodules(
        root_module=root_module,
        predicate=lambda x: isinstance(x, nn.BatchNorm2d),
        func=lambda x: nn.GroupNorm(
            num_groups=x.num_features//features_per_group,
            num_channels=x.num_features)
    )
    return root_module


# construct ResNet18 encoder
# if you have multiple camera views, use seperate encoder weights for each view.
vision_encoder = get_resnet("resnet18", weights=None)

# IMPORTANT!
# replace all BatchNorm with GroupNorm to work with EMA
# performance will tank if you forget to do this!
vision_encoder = replace_bn_with_gn(vision_encoder)

vision_encoder
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): GroupNorm(4, 64, eps=1e-05, affine=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GroupNorm(4, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): GroupNorm(4, 64, eps=1e-05, affine=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): GroupNorm(4, 64, eps=1e-05, affine=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
count_parameters(get_resnet("resnet18", weights=None))
# Out:
# 11176512

# %% [markdown]
# # R3M

# %%
import r3m

# %%
#r3m.device = 'cpu'
model = r3m.load_r3m("resnet18")
r3m_model = model.module
r3m_model
# Out:
# /home/thankgod/conda/envs/msc_conda_env/lib/python3.9/site-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /home/thankgod/conda/envs/msc_conda_env/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/thankgod/conda/envs/msc_conda_env/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# R3M(
#   (cs): CosineSimilarity()
#   (bce): BCELoss()
#   (sigm): Sigmoid()
#   (convnet): ResNet(
# ...

# %%
resnet_model = r3m_model.convnet
resnet_model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
class ResNetVisionEncoderNoPretrained(torch.nn.Module):
    def __init__(self, config_name):
        super().__init__()
        config = AutoConfig.from_pretrained(config_name)
        self.processor = AutoImageProcessor.from_pretrained(config_name)
        self.resnet = AutoModel.from_config(
            config,
            #device_map='auto'
        )

    def forward(self, x):
        # x shape: [batch, 3, H, W]
        outputs = self.resnet(x)
        return outputs.pooler_output.flatten(start_dim=1)

# %% [markdown]
# # Dino

# %%
import torch

# %%
# model checkpoints
dino_convnext_model_checkpoint = "facebook/dinov3-convnext-tiny-pretrain-lvd1689m"
dino_vit_model_checkpoint = "facebook/dinov3-vits16plus-pretrain-lvd1689m"
resnet_model_checkpoint = "microsoft/resnet-18"

# %%
# processors
processor = AutoImageProcessor.from_pretrained(dino_convnext_model_checkpoint)
processor = AutoImageProcessor.from_pretrained(dino_convnext_model_checkpoint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # processors
# ----> 2 processor = AutoImageProcessor.from_pretrained(dino_convnext_model_checkpoint)
#       3 processor = AutoImageProcessor.from_pretrained(dino_convnext_model_checkpoint)
#
# NameError: name 'AutoImageProcessor' is not defined

# %%
# no pretrained
config = AutoConfig.from_pretrained(dino_convnext_model_checkpoint)
config_model = AutoModel.from_config(config)
print(config_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # no pretrained
# ----> 2 config = AutoConfig.from_pretrained(dino_convnext_model_checkpoint)
#       3 config_model = AutoModel.from_config(config)
#       4 print(config_model)
#
# NameError: name 'AutoConfig' is not defined

# %%
# from pretrained
pretrained_model = AutoModel.from_pretrained(
    dino_convnext_model_checkpoint,
    device_map="auto",
)

# %%
type(model)
# Out:
# torch.nn.parallel.data_parallel.DataParallel

# %%
print(isinstance(model, torch.nn.Module))  # True
# Out:
# True

# %%
model
# Out:
# DataParallel(
#   (module): R3M(
#     (cs): CosineSimilarity()
#     (bce): BCELoss()
#     (sigm): Sigmoid()
#     (convnet): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
# ...

# %%
image = torch.zeros((1, 3, 96, 96))
inputs = processor(images=image, return_tensors="pt").to(model.device)
with torch.inference_mode():
    outputs = model(**inputs)

pooled_output = outputs.pooler_output
print("Pooled output shape:", pooled_output.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 image = torch.zeros((1, 3, 96, 96))
# ----> 2 inputs = processor(images=image, return_tensors="pt").to(model.device)
#       3 with torch.inference_mode():
#       4     outputs = model(**inputs)
#
# File ~/conda/envs/msc_conda_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1962, in Module.__getattr__(self, name)
#    1960     if name in modules:
#    1961         return modules[name]
# -> 1962 raise AttributeError(
#    1963     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1964 )
#
# AttributeError: 'DataParallel' object has no attribute 'device'

# %%
inputs = processor(images=image, return_tensors="pt").to(model.device)
with torch.inference_mode():
    outputs = model(**inputs)

pooled_output = outputs.pooler_output
print("Pooled output shape:", pooled_output.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 inputs = processor(images=image, return_tensors="pt").to(model.device)
#       2 with torch.inference_mode():
#       3     outputs = model(**inputs)
#
# File ~/conda/envs/msc_conda_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1962, in Module.__getattr__(self, name)
#    1960     if name in modules:
#    1961         return modules[name]
# -> 1962 raise AttributeError(
#    1963     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1964 )
#
# AttributeError: 'DataParallel' object has no attribute 'device'

# %%
# import torch.nn as nn
# from transformers.models.dinov3_convnext.modeling_dinov3_convnext import (
#     DINOv3ConvNextModel,
# )


# class DinoV3Wrapper(nn.Module):
#     def __init__(self, pretrained=True):
#         super().__init__()
#         if pretrained:
#             self.model = DINOv3ConvNextModel.from_pretrained("facebook/dinov3-small")
#         else:
#             from transformers import DINOv3ConvNextConfig
#             self.model = DINOv3ConvNextModel(DINOv3ConvNextConfig())

#     def forward(self, x):
#         return self.model(x).last_hidden_state

# %%
import torch.nn as nn


class EncoderModel(nn.Module):
    def __init__(self, checkpoint='name', pretrained=True):
        super().__init__()
        if pretrained:
            self.model = AutoModel.from_pretrained(
                            checkpoint,
                            device_map="cpu",
                        )
        else:
            config = AutoConfig.from_pretrained(checkpoint)
            self.model = AutoModel.from_config(config)

    def forward(self, x):
        return self.model(x)



# model checkpoints
dino_convnext_model_checkpoint = "facebook/dinov3-convnext-tiny-pretrain-lvd1689m"
dino_vit_model_checkpoint = "facebook/dinov3-vits16plus-pretrain-lvd1689m"
resnet_model_checkpoint = "microsoft/resnet-18"


image = torch.zeros((1, 3, 96, 96))
model = EncoderModel(checkpoint=dino_convnext_model_checkpoint, pretrained=False)

# %%
model(image).last_hidden_state.shape
# Out:
# torch.Size([1, 10, 768])

# %%
print(model)
# Out:
# EncoderModel(
#   (model): DINOv3ConvNextModel(
#     (stages): ModuleList(
#       (0): DINOv3ConvNextStage(
#         (downsample_layers): ModuleList(
#           (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#           (1): DINOv3ConvNextLayerNorm((96,), eps=1e-06, elementwise_affine=True)
#         )
#         (layers): ModuleList(
#           (0-2): 3 x DINOv3ConvNextLayer(
#             (depthwise_conv): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#             (layer_norm): DINOv3ConvNextLayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (pointwise_conv1): Linear(in_features=96, out_features=384, bias=True)
#             (activation_fn): GELUActivation()
#             (pointwise_conv2): Linear(in_features=384, out_features=96, bias=True)
#             (drop_path): Identity()
#           )
#         )
#       )
#       (1): DINOv3ConvNextStage(
#         (downsample_layers): ModuleList(
# ...

# %%
import os
import sys

import torch

src_parent = os.path.abspath(os.path.join(os.path.dirname(os.getcwd())))
sys.path.append(src_parent)

# %%
src_parent
# Out:
# '/home/thankgod/2025/msc_project/src'

# %%
import hydra
from omegaconf import OmegaConf
from torch.utils.data import DataLoader

cfg = OmegaConf.load('../data/task/train_config/lift_config.yaml')
cfg = OmegaConf.load('../data/task/train_config/pusht_config.yaml')
##cfg = OmegaConf.load('../pusht_config.yaml')

#cfg = OmegaConf.load('../lift_config.yaml')

# %%
print(cfg.work_dir)
print(cfg.task.dataset.zarr_path)
# Out:
# /home/thankgod/2025/msc_project
# src/data/task/pusht/pusht_cchi_v7_replay.zarr

# %%
import os

os.path.expanduser('/home/thankgod/2025/msc_project')
# Out:
# '/home/thankgod/2025/msc_project'

# %%
cfg.task.dataset
# Out:
# {'_target_': 'diffusion_policy.dataset.pusht_image_dataset.PushTImageDataset', 'horizon': 16, 'max_train_episodes': 90, 'pad_after': 7, 'pad_before': 1, 'seed': 42, 'val_ratio': 0.02, 'zarr_path': 'src/data/task/pusht/pusht_cchi_v7_replay.zarr'}

# %%
dataset = hydra.utils.instantiate(cfg.task.dataset)

# train dataset
train_dataloader = DataLoader(dataset, **cfg.dataloader)
normalizer = dataset.get_normalizer()

# configure validation dataset
val_dataset = dataset.get_validation_dataset()
val_dataloader = DataLoader(val_dataset, **cfg.val_dataloader)
# Out:
# ---------------------------------------------------------------------------
# PathNotFoundError                         Traceback (most recent call last)
# File ~/conda/envs/msc_conda_env/lib/python3.9/site-packages/hydra/_internal/instantiate/_instantiate2.py:92, in _call_target(_target_, _partial_, args, kwargs, full_key)
#      91 try:
# ---> 92     return _target_(*args, **kwargs)
#      93 except Exception as e:
#
# File ~/2025/msc_project/src/diffusion_policy/dataset/pusht_image_dataset.py:25, in PushTImageDataset.__init__(self, zarr_path, horizon, pad_before, pad_after, seed, val_ratio, max_train_episodes)
#      24 super().__init__()
# ---> 25 self.replay_buffer = ReplayBuffer.copy_from_path(
#      26     zarr_path, keys=['img', 'state', 'action'])
#      27 val_mask = get_val_mask(
#      28     n_episodes=self.replay_buffer.n_episodes,
#      29     val_ratio=val_ratio,
#      30     seed=seed)
#
# ...

# %%
batch = next(iter(train_dataloader))
batch.keys()
# Out:
# dict_keys(['obs', 'action'])

# %%
#batch['obs']

# %%
model = hydra.utils.instantiate(cfg.policy)

# %%
from rich import print

from diffusion_policy.common.pytorch_util import dict_apply, optimizer_to
from diffusion_policy.model.vision.model_getter import get_rgb_model
from diffusion_policy.model.vision.multi_image_obs_encoder import MultiImageObsEncoder

# %%
# device = torch.device(cfg.training.device)
# model.to(device)
batch = dict_apply(batch, lambda x: x.to('cpu', non_blocking=True))

# %%
cfg
# Out:
# {'defaults': ['_self_', {'task': 'pusht_image'}], 'name': 'train_diffusion_unet_image', '_target_': 'diffusion_policy.workspace.train_diffusion_unet_image_workspace.TrainDiffusionUnetImageWorkspace', 'task_name': 'pusht_image', 'exp_name': 'default', 'horizon': 16, 'n_obs_steps': 2, 'n_action_steps': 8, 'n_latency_steps': 0, 'dataset_obs_steps': '${n_obs_steps}', 'past_action_visible': False, 'keypoint_visible_rate': 1.0, 'obs_as_global_cond': True, 'shape_meta': {'action': {'shape': [2]}, 'obs': {'agent_pos': {'shape': [2], 'type': 'low_dim'}, 'image': {'shape': [3, 96, 96], 'type': 'rgb'}}}, 'task': {'dataset': {'_target_': 'diffusion_policy.dataset.pusht_image_dataset.PushTImageDataset', 'horizon': 16, 'max_train_episodes': 90, 'pad_after': 7, 'pad_before': 1, 'seed': 42, 'val_ratio': 0.02, 'zarr_path': '/home/thankgod/2025/msc_project/src/data/pusht/pusht_cchi_v7_replay.zarr'}, 'env_runner': {'_target_': 'diffusion_policy.env_runner.pusht_image_runner.PushTImageRunner', 'fps': 10
# ...

# %%
shape_meta = cfg['shape_meta']
shape_meta
# Out:
# {'action': {'shape': [2]}, 'obs': {'agent_pos': {'shape': [2], 'type': 'low_dim'}, 'image': {'shape': [3, 96, 96], 'type': 'rgb'}}}

# %%
shape_meta['obs']
# Out:
# {'agent_pos': {'shape': [2], 'type': 'low_dim'}, 'image': {'shape': [3, 96, 96], 'type': 'rgb'}}

# %%
dino_convnext_model_checkpoint = "facebook/dinov3-convnext-tiny-pretrain-lvd1689m"
dino_vit_model_checkpoint = "facebook/dinov3-vits16plus-pretrain-lvd1689m"
resnet_model_checkpoint = "microsoft/resnet-18"

# %%
shape_meta
# Out:
# {'action': {'shape': [2]}, 'obs': {'agent_pos': {'shape': [2], 'type': 'low_dim'}, 'image': {'shape': [3, 96, 96], 'type': 'rgb'}}}

# %%
#rgb_model = get_rgb_model('resnet', weights=None)

# ResNet18 with ImageNet weights
model1 = get_rgb_model("resnet18", weights="IMAGENET1K_V1")

# ResNet50 with R3M weights
#model2 = get_rgb_model("resnet50", weights="r3m")

# Hugging Face encoder (e.g., BERT)
model3 = get_rgb_model(dino_vit_model_checkpoint, pretrained=True)

# Hugging Face encoder from config only (no weights)
model4 = get_rgb_model(dino_convnext_model_checkpoint, pretrained=False)

# %%
resnet_model = MultiImageObsEncoder(shape_meta, model1)
dino_model_vit = MultiImageObsEncoder(shape_meta, model3)
dino_model_conv = MultiImageObsEncoder(shape_meta, model4)

# %%
# batch_image = batch['obs']['image']
# batch_image.shape

image = torch.zeros((1, 3, 96, 96))

# %%
transform = resnet_model.key_model_map.image(image)
transform
# Out:
# tensor([[0.8788, 0.8921, 0.9034, 1.0182, 0.9518, 0.8914, 0.9814, 1.1773, 1.0253,
#          1.0090, 0.7929, 0.8409, 0.9392, 0.9165, 1.0427, 1.0008, 0.8834, 1.3829,
#          0.9824, 0.8800, 0.9246, 1.0691, 1.0186, 1.0458, 1.0136, 0.9232, 1.0929,
#          1.0015, 0.9538, 0.8967, 1.0403, 0.7671, 0.9833, 0.8836, 0.8628, 0.9050,
#          0.9812, 1.0477, 0.9764, 0.8820, 0.8572, 0.9309, 0.9177, 0.9066, 0.9239,
#          0.9332, 0.9256, 1.1981, 0.9053, 0.8687, 0.9754, 0.9719, 0.8659, 0.9716,
#          1.0331, 0.9856, 1.1703, 0.9700, 1.0875, 0.9667, 0.8890, 1.0164, 1.0109,
#          0.8845, 1.0079, 0.9818, 0.9027, 1.0243, 1.0306, 0.8799, 1.0603, 0.8751,
#          0.9746, 0.8905, 0.9948, 0.9651, 0.9467, 0.9270, 0.9228, 0.9208, 0.9034,
#          1.0769, 1.0830, 1.1243, 0.8577, 0.7948, 0.9515, 0.9531, 0.8738, 0.8527,
#          0.9091, 1.0194, 0.8529, 1.0512, 0.8993, 0.9016, 1.0138, 0.9797, 1.0962,
#          0.8808, 0.9420, 0.8699, 0.7935, 1.0495, 0.9768, 0.8908, 0.8967, 1.0415,
# ...

# %%
print(transform.shape, type(transform))
# Out:
# torch.Size([1, 512])
# <class 'torch.Tensor'>

# %%
print(resnet_model.key_model_map)
# Out:
# ModuleDict(
#   (image): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
dino_model_conv.key_model_map.image(image).keys()
# Out:
# odict_keys(['last_hidden_state', 'pooler_output'])

# %%
dino_model_vit.key_model_map.image(image)
# Out:
# BaseModelOutputWithPooling(last_hidden_state=tensor([[[-0.2480,  0.2974,  0.8368,  ...,  0.9002, -0.6170, -0.7409],
#          [-0.0068,  0.0487,  0.2386,  ...,  0.0664, -0.1052, -0.0733],
#          [-0.3057, -0.6216,  0.6132,  ...,  0.6123,  0.0198, -0.5288],
#          ...,
#          [ 0.1578,  0.1961,  0.4225,  ...,  0.4887, -0.4941, -0.2030],
#          [ 0.1261,  0.2420,  0.4281,  ...,  0.5045, -0.5087, -0.2034],
#          [ 0.0498,  0.2892,  0.4355,  ...,  0.5808, -0.6565, -0.2117]]],
#        grad_fn=<NativeLayerNormBackward0>), pooler_output=tensor([[-2.4804e-01,  2.9741e-01,  8.3679e-01, -2.0962e+00, -4.3029e-01,
#          -3.4638e-01,  6.8483e-01, -4.1272e-01,  1.3526e+00,  3.9409e-01,
#           6.3825e-01, -2.7511e-02,  2.8998e-01,  2.6580e-01,  5.1794e-01,
#          -9.9043e-01, -4.7473e-01,  9.8694e-01, -5.4664e-01,  1.1010e+00,
#           1.0285e-01,  1.1579e+00, -5.5905e-01, -3.1043e-01,  5.9279e-01,
# ...

# %%
print(dino_model.key_model_map)
# Out:
# ModuleDict(
#   (image): EncoderModel(
#     (model): DINOv3ViTModel(
#       (embeddings): DINOv3ViTEmbeddings(
#         (patch_embeddings): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (rope_embeddings): DINOv3ViTRopePositionEmbedding()
#       (layer): ModuleList(
#         (0-11): 12 x DINOv3ViTLayer(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attention): DINOv3ViTAttention(
#             (k_proj): Linear(in_features=384, out_features=384, bias=False)
#             (v_proj): Linear(in_features=384, out_features=384, bias=True)
#             (q_proj): Linear(in_features=384, out_features=384, bias=True)
#             (o_proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (layer_scale1): DINOv3ViTLayerScale()
#           (drop_path): Identity()
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): DINOv3ViTGatedMLP(
# ...

# %% [markdown]
# # EfficientNet Embedding

# %%
efficientnet_model = torchvision.models.get_model("efficientnet_b0", weights=None)
print(efficientnet_model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
# ...

# %%
list(efficientnet_model.children())[-1]
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
list(resnet_model.children())[-1]
# Out:
# Identity()

# %%
list(mobilenet.children())[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 list(mobilenet.children())[-1]
#
# NameError: name 'mobilenet' is not defined

# %%
print("Before:", list(efficientnet_model.children())[-1])
# Out:
# Before: Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )

# %%
# Out:
# After: Identity()

# %%
count_parameters(efficientnet_model)
# Out:
# 5288548

# %% [markdown]
# # MobileNet

# %%
#1.mobilenet_v2, mobilenet_v3_small, mobilenet_v3_large

# %%
mobilenet = torchvision.models.get_model("mobilenet_v3_small", weights=None)
print(mobilenet)
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
# ...

# %%
count_parameters(mobilenet)
# Out:
# 2542856

# %%
import math

# %% [markdown]
# # Model cleaning

# %%
def replace_last_layer_with_identity(model: nn.Module):
    """Replace the last layer of a model with nn.Identity."""
    children_list = list(model.named_children())
    if not children_list:
        raise ValueError("Model has no child layers to replace.")
    last_name, _ = children_list[-1]
    setattr(model, last_name, nn.Identity())
    return model

# Example usage:
efficientnet_model = replace_last_layer_with_identity(mobilenet)
print("After:", list(efficientnet_model.children())[-1])
# Out:
# After: Identity()

# %%
from typing import Callable

import torch.nn as nn


def replace_submodules(
    root_module: nn.Module,
    predicate: Callable[[nn.Module], bool],
    func: Callable[[nn.Module], nn.Module]
) -> nn.Module:
    """Replace all submodules that match the predicate."""
    if predicate(root_module):
        return func(root_module)

    matches = [k.split('.') for k, m
        in root_module.named_modules(remove_duplicate=True)
        if predicate(m)]

    for *parent, k in matches:
        parent_module = root_module
        if parent:
            parent_module = root_module.get_submodule('.'.join(parent))

        src_module = parent_module[int(k)] if isinstance(parent_module, nn.Sequential) else getattr(parent_module, k)
        tgt_module = func(src_module)

        if isinstance(parent_module, nn.Sequential):
            parent_module[int(k)] = tgt_module
        else:
            setattr(parent_module, k, tgt_module)

    assert not any(predicate(m) for _, m in root_module.named_modules(remove_duplicate=True))
    return root_module


# --- Step 1: Replace last classifier layer with Identity ---
def replace_last_classifier_with_identity(model: nn.Module) -> nn.Module:
    """Replace the last top-level child module with nn.Identity."""
    children_list = list(model.named_children())
    if not children_list:
        raise ValueError("Model has no child layers to replace.")
    last_name, _ = children_list[-1]
    setattr(model, last_name, nn.Identity())
    return model


# --- Step 2: Replace BatchNorm with GroupNorm ---
def replace_bn_with_gn(model: nn.Module, features_per_group: int = 16) -> nn.Module:
    """Replace all BatchNorm2d layers with GroupNorm, adjusting groups if needed."""
    def bn_to_gn(x: nn.BatchNorm2d) -> nn.GroupNorm:
        num_channels = x.num_features
        # Pick a valid number of groups
        num_groups = max(1, num_channels // features_per_group)
        # Ensure divisibility
        if num_channels % num_groups != 0:
            num_groups = math.gcd(num_channels, features_per_group) or 1
        return nn.GroupNorm(num_groups=num_groups, num_channels=num_channels)

    return replace_submodules(
        root_module=model,
        predicate=lambda m: isinstance(m, nn.BatchNorm2d),
        func=bn_to_gn
    )



def get_model(name):
    model = torchvision.models.get_model(name, weights=None)
    return model


# resnet18 efficientnet_b0 mobilenet_v2 mobilenet_v3_small mobilenet_v3_large

# Example usage
model = get_model("mobilenet_v2")
model = replace_last_classifier_with_identity(model)
model = replace_bn_with_gn(model)

model
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): GroupNorm(2, 32, eps=1e-05, affine=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): GroupNorm(2, 32, eps=1e-05, affine=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): GroupNorm(1, 16, eps=1e-05, affine=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): GroupNorm(6, 96, eps=1e-05, affine=True)
#           (2): ReLU6(inplace=True)
#         )
# ...
