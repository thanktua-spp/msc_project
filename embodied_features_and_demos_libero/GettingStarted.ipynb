# %%
import json
import pprint

import tensorflow as tf
import tensorflow_datasets as tfds
from PIL import Image
# Out:
# 2025-08-01 19:31:03.804453: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-01 19:31:04.068047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754073064.181536 1756930 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754073064.228317 1756930 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Load the LIBERO tfds dataset
tf.config.set_visible_devices(
    [], device_type="gpu"
)
dataset_name = "libero_lm_90"
print(f"Loading data from dataset: {dataset_name}")
builder = tfds.builder_from_directory("/PATH/TO/embodied_features_libero/libero_lm_90/1.0.0")
ds = builder.as_dataset(split='train')

# %%
# Load the LIBERO reasonings
with open("/PATH/TO/embodied_features_libero/libero_reasonings.json") as f:
    reasoning_data = json.load(f)

# %%
# Iterate through the dataset to get an episode
for ep in ds:
    ep_path = ep["episode_metadata"]["file_path"].numpy().decode("utf-8")
    demo_id = str(ep["episode_metadata"]["demo_id"].numpy())
    break

# Iterate through the steps of the episode
for step_idx, step in enumerate(ep["steps"]):
    break

# The episode path, demo ID, and step index all you to index into the reasoning data
reasoning = reasoning_data[ep_path][demo_id][str(step_idx)]

# %%
# You can access the observation with the following
Image.fromarray(step["observation"]["image"].numpy())

# %%
# You can also view the reasoning and action for the step
pprint.pp(reasoning)
print(step["action"].numpy())
